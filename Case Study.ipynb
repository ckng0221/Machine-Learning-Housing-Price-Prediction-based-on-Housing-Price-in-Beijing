# %% [markdown]
# # 3.0 Methodology

# %% [markdown]
# # 3.1 Data Collection

# %% [markdown]
# ## Import Libraries

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import dataset

# %%
filename = 'new.csv'
housing_raw = pd.read_csv(filename, encoding= 'unicode_escape')


IMAGES_PATH = 'Images'
# Out:
# C:\Users\ck_ng\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (1,11,12,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # 3.2 Explorary Data Analysis (EDA)

# %% [markdown]
# ## Examine data type

# %%
print(housing_raw.dtypes)
# Out:
# url                     object
# id                      object
# Lng                    float64
# Lat                    float64
# Cid                      int64
# tradeTime               object
# DOM                    float64
# followers                int64
# totalPrice             float64
# price                    int64
# square                 float64
# livingRoom              object
# drawingRoom             object
# kitchen                  int64
# bathRoom                object
# floor                   object
# buildingType           float64
# constructionTime        object
# renovationCondition      int64
# buildingStructure        int64
# ladderRatio            float64
# elevator               float64
# fiveYearsProperty      float64
# subway                 float64
# district                 int64
# communityAverage       float64
# dtype: object

# %% [markdown]
# ## Examine the basic summary of data

# %%
housing_raw.describe()
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  318851.000000  318851.000000  3.188510e+05  160874.000000
# mean      116.418459      39.949591  1.129113e+12      28.822339
# std         0.112054       0.091983  2.363447e+12      50.237343
# min       116.072514      39.627030  1.111027e+12       1.000000
# 25%       116.344985      39.893200  1.111027e+12       1.000000
# 50%       116.416780      39.934527  1.111027e+12       6.000000
# 75%       116.477581      40.003018  1.111027e+12      37.000000
# max       116.732378      40.252758  1.114620e+15    1677.000000
#
#            followers     totalPrice          price         square  \
# count  318851.000000  318851.000000  318851.000000  318851.000000
# mean       16.731508     349.030201   43530.436379      83.240597
# std        34.209185     230.780778   21709.024204      37.234661
# min         0.000000       0.100000       1.000000       6.900000
# 25%         0.000000     205.000000   28050.000000      57.900000
# 50%         5.000000     294.000000   38737.000000      74.260000
# 75%        18.000000     425.500000   53819.500000      98.710000
# max      1143.000000   18130.000000  156250.000000    1745.500000
#
#              kitchen   buildingType  renovationCondition  buildingStructure  \
# count  318851.000000  316830.000000        318851.000000      318851.000000
# mean        0.994599       3.009790             2.606330           4.451026
# std         0.109609       1.269857             1.311739           1.901753
# min         0.000000       0.048000             0.000000           0.000000
# 25%         1.000000       1.000000             1.000000           2.000000
# 50%         1.000000       4.000000             3.000000           6.000000
# 75%         1.000000       4.000000             4.000000           6.000000
# max         4.000000       4.000000             4.000000           6.000000
#
#         ladderRatio       elevator  fiveYearsProperty         subway  \
# count  3.188510e+05  318819.000000      318819.000000  318819.000000
# mean   6.316486e+01       0.577055           0.645601       0.601112
# std    2.506851e+04       0.494028           0.478331       0.489670
# min    0.000000e+00       0.000000           0.000000       0.000000
# 25%    2.500000e-01       0.000000           0.000000       0.000000
# 50%    3.330000e-01       1.000000           1.000000       1.000000
# 75%    5.000000e-01       1.000000           1.000000       1.000000
# max    1.000940e+07       1.000000           1.000000       1.000000
#
#             district  communityAverage
# count  318851.000000     318388.000000
# mean        6.763564      63682.446305
# std         2.812616      22329.215447
# min         1.000000      10847.000000
# 25%         6.000000      46339.000000
# 50%         7.000000      59015.000000
# 75%         8.000000      75950.000000
# max        13.000000     183109.000000

# %% [markdown]
# ## View the first 5 rows of the data set

# %%
housing_raw.head()
# Out:
#                                                  url            id  \
# 0  https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1  https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2  https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3  https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4  https://bj.lianjia.com/chengjiao/101086920653....  101086920653
#
#           Lng        Lat            Cid   tradeTime     DOM  followers  \
# 0  116.475489  40.019520  1111027376244  2016-08-09  1464.0        106
# 1  116.453917  39.881534  1111027381879  2016-07-28   903.0        126
# 2  116.561978  39.877145  1111040862969  2016-12-11  1271.0         48
# 3  116.438010  40.076114  1111043185817  2016-09-30   965.0        138
# 4  116.428392  39.886229  1111027381174  2016-08-28   927.0        286
#
#    totalPrice  price  ...  buildingType constructionTime renovationCondition  \
# 0       415.0  31680  ...           1.0             2005                   3
# 1       575.0  43436  ...           1.0             2004                   4
# 2      1030.0  52021  ...           4.0             2005                   3
# 3       297.5  22202  ...           1.0             2008                   1
# 4       392.0  48396  ...           4.0             1960                   2
#
#    buildingStructure ladderRatio elevator  fiveYearsProperty subway  district  \
# 0                  6       0.217      1.0                0.0    1.0         7
# 1                  6       0.667      1.0                1.0    0.0         7
# 2                  6       0.500      1.0                0.0    0.0         7
# 3                  6       0.273      1.0                0.0    0.0         6
# 4                  2       0.333      0.0                1.0    1.0         1
#
#    communityAverage
# 0           56021.0
# 1           71539.0
# 2           48160.0
# 3           51238.0
# 4           62588.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Examine the destribution of housing price

# %%
ax = housing_raw.price.plot.hist(bins=1000, 
                                 title='Distribution of Housing Price (Original)');
ax.set_xlabel("Housing Price (RMB/m2)");

# %% [markdown]
# ## Preliminary study of the relationship

# %%
housing_raw.corr(method='pearson')['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# communityAverage       0.683768
# totalPrice             0.622658
# renovationCondition    0.294859
# followers              0.257173
# subway                 0.232571
# DOM                    0.215473
# elevator               0.050528
# buildingStructure      0.042889
# district               0.034186
# fiveYearsProperty      0.014151
# kitchen                0.013289
# ladderRatio            0.001107
# Cid                   -0.000387
# buildingType          -0.048676
# Lat                   -0.052004
# Lng                   -0.153212
# square                -0.164734
# Name: price, dtype: float64

# %% [markdown]
# It appears that the "communityAverage" has the highest positive linear relationship, whereas the "square" has highest negative linear relationship"

# %% [markdown]
# ## Pairplot

# %% [markdown]
# Pair plot to visualize the relationship between each feature

# %%
import seaborn as sns;
sns.pairplot(housing_raw[['price', 'communityAverage', 'totalPrice', 'followers',
                      'renovationCondition', 'square', 'Lng', 'Lat']], diag_kind='kde');

# %% [markdown]
# Appears that only 'communityAverage' have somewhat a linear relationship with our target 'Price'

# %% [markdown]
# # 3.1 Data Cleaning

# %% [markdown]
# ## Remove outliers in the data

# %%
# create a copy of Raw
housing = housing_raw.copy()

# Remove non-real numbers
housing = housing[housing.livingRoom.apply(np.isreal)]

def remove_outlier(df, variable):
    """
    For removing outliers based on IQR method
    
    Parameters
    ----------
    df : pandas dataframe
    variable : str, column name of the dataframe
    """
    # Computing IQR
    Q1 = df[variable].quantile(0.25)
    Q3 = df[variable].quantile(0.75)
    IQR = Q3 - Q1

    # Filtering Values between Q1-1.5IQR and Q3+1.5IQR
    filtered = df.query(f'(@Q1 - 1.5 * @IQR) <= {variable} <= (@Q3 + 1.5 * @IQR)').reset_index(drop=True)
    return filtered

# Remove Outlier based on price
housing = remove_outlier(housing, 'price')

# Drop unneeded columns
housing.drop(['url', 'id', 'Cid'], axis=1, inplace=True)

# %% [markdown]
# ## New distribution of housing price after removal of outliers

# %%
ax = housing.price.plot.hist(bins=1000, 
                        title='Distribution of Housing Price (New)')
ax.set_xlabel("Housing Price (RMB/m2)");

# %% [markdown]
# # 3.4 Data Visualization

# %% [markdown]
# ## Functions for visualization

# %%
def show_map(df, variable, scale=1., sep='k', tick_n=11, heatmap_label=None):
    """For plotting distribution on map"""
    import matplotlib.image as mpimg
    beijing_img = mpimg.imread('Images/beijingmap_baidu.png') #baidu
    
    ax = df.plot(kind='scatter', x="Lng", y='Lat', alpha=0.04,
                 s=df["followers"]/2, label="Followers",
                 c=variable, cmap=plt.get_cmap("jet"),
                 colorbar=False, figsize=(20, 10))
    plt.imshow(beijing_img, extent=[115.1946, 117.48, 39.495, 40.33], alpha=0.6,   
               cmap=plt.get_cmap("jet")) # baidu

    plt.ylabel("Latitude", fontsize=12)
    plt.xlabel("Longitude", fontsize=12)

    prices = df[variable] * scale
    tick_values = np.linspace(prices.min(), prices.max(), tick_n)
    cbar = plt.colorbar(ticks=tick_values / prices.max(), fraction=0.046, pad=0.04)
    
    def separator(sep):
        if sep == 'k': #thousand separator
            sep_ = 'k'
            div = 1_000
        elif sep == 'M': #million separator
            sep_ ='M'
            div = 1_000_000
        elif sep == None:
            sep_ = ''
            div = 1
            
        cbar.ax.set_yticklabels([f"%d{sep_}"%round((v/div)) for v in tick_values], fontsize=12)
        
    separator(sep)
    cbar.set_label(heatmap_label, fontsize=12)

    plt.legend(fontsize=16)

    plt.xlim([115.9, 116.8])
    plt.ylim([39.5, 40.3])
    plt.show()
    
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    """Save plotted figure"""
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ## Distribution of Housing Price

# %%
# Display the distribution of housing price at Beijing Area
show_map(housing, "price", heatmap_label='House Price [RMB/m2]')

# %% [markdown]
# It appears that the center of the Beijing has the higher price, and the price decreaases as they are moving further away from the center

# %% [markdown]
# ## Visualize for community average and tradeTime

# %%
# groupby the tradeTime & community pivot variables
tradetime_pivot = housing.groupby('tradeTime')['price'].mean()
community_pivot = housing.groupby('communityAverage')['price'].mean()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

f1 = plt.figure(figsize=(15, 5))
f2 = plt.figure(figsize=(15, 5))
ax1 = f1.add_subplot(111)
ax1.scatter(tradetime_pivot.index, tradetime_pivot.values,color='red', alpha=0.3)
ax1.set(xlabel='Dates', ylabel='Average Price (RMB)')
ax1.xaxis.set_major_locator(mdates.MinuteLocator(interval=60*24*365)) # # tickmark frequency'
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y')) 

ax2 = f2.add_subplot(111)
ax2.scatter(community_pivot.index, community_pivot.values, alpha=0.3)
ax2.set(xlabel='Community Average', ylabel='Average Price (RMB)')
plt.show()

# %% [markdown]
# Shows that the price increase over time, and generally have a linear relationship between average price & community average

# %% [markdown]
# # 3.5 Machine Learning

# %% [markdown]
# # 3.5.1 Feature Engineering

# %% [markdown]
# ## Feature Selection

# %%
house = housing.copy()

# Drop DOM & totalPrice
house.drop(columns=['totalPrice', 'communityAverage'], inplace=True)

# %% [markdown]
# - 'totalPrice' is dropped, as we can directly calculate target unit price based on the 'totalPrice' divided by 'square' the area of the house already, which gives an unfair prediction
# - 'communityAverage' is dropped with similar reason, although no direct relationship, this variable already give a hint what the price range would be, so will make the price predictor less useful

# %% [markdown]
# ## Feature Transformation

# %%
# Convert Trading time to year only
house.tradeTime = pd.to_datetime(house.tradeTime).dt.strftime("%Y")

# convert desired data to numeric 
house['tradeTime'] = pd.to_numeric(house['tradeTime'])
house['livingRoom'] = house['livingRoom'].apply(pd.to_numeric, errors='coerce')
house['drawingRoom'] = house['drawingRoom'].apply(pd.to_numeric, errors='coerce')
house['bathRoom'] = house['bathRoom'].apply(pd.to_numeric, errors='coerce')
house['constructionTime'] = house['constructionTime'].apply(pd.to_numeric, errors='coerce')

# Convert the floor to numeric
house.floor = house.floor.str.split(' ').str[1].astype('float')

# %%
# Check null data
house.isna().mean().sort_values(ascending=False)
# Out:
# DOM                    0.382002
# constructionTime       0.059138
# buildingType           0.005971
# district               0.000000
# drawingRoom            0.000000
# Lat                    0.000000
# tradeTime              0.000000
# followers              0.000000
# price                  0.000000
# square                 0.000000
# livingRoom             0.000000
# bathRoom               0.000000
# kitchen                0.000000
# subway                 0.000000
# floor                  0.000000
# renovationCondition    0.000000
# buildingStructure      0.000000
# ladderRatio            0.000000
# elevator               0.000000
# fiveYearsProperty      0.000000
# Lng                    0.000000
# dtype: float64

# %% [markdown]
# ## Check correlation

# %%
## Check correlation
corr = house.corr()['price'].sort_values(ascending=False)
corr
# Out:
# price                  1.000000
# tradeTime              0.447050
# subway                 0.289839
# renovationCondition    0.252012
# followers              0.201779
# DOM                    0.149165
# elevator               0.068200
# floor                  0.050227
# buildingStructure      0.044247
# kitchen                0.016261
# ladderRatio            0.002853
# fiveYearsProperty     -0.006965
# livingRoom            -0.044385
# bathRoom              -0.045313
# Lat                   -0.054322
# buildingType          -0.064838
# drawingRoom           -0.090902
# square                -0.122343
# constructionTime      -0.190963
# district              -0.213320
# Lng                   -0.300616
# Name: price, dtype: float64

# %% [markdown]
# ## 3.1 Check significance of the correlation

# %%
from scipy.stats.stats import pearsonr

housing_corr = housing.dropna() # dropna for correlation significant test
for column in housing_corr:
    try:
        coefficient, pvalue = pearsonr(housing_corr[column], housing_corr.price)
        if pvalue <= 0.05:
            signif = 'Significant'
        else: 
            signif = 'Not Significant'
            
        print(f"{column} : {pvalue} ({signif})")
    except TypeError:
        pass # pass for non-numeric
# Out:
# Lng : 0.0 (Significant)
# Lat : 5.37959749575885e-77 (Significant)
# DOM : 0.0 (Significant)
# followers : 0.0 (Significant)
# totalPrice : 0.0 (Significant)
# price : 0.0 (Significant)
# square : 0.0 (Significant)
# livingRoom : 2.3146073388651423e-77 (Significant)
# drawingRoom : 3.284291073595476e-153 (Significant)
# kitchen : 1.502704591808757e-20 (Significant)
# bathRoom : 1.9398351120344218e-86 (Significant)
# buildingType : 1.5248644612175487e-82 (Significant)
# renovationCondition : 0.0 (Significant)
# buildingStructure : 1.1702122174052774e-46 (Significant)
# ladderRatio : 0.3844034184575325 (Not Significant)
# elevator : 1.9032496713893712e-78 (Significant)
# fiveYearsProperty : 0.00047288418460049507 (Significant)
# subway : 0.0 (Significant)
# district : 2.253062848215524e-283 (Significant)
# communityAverage : 0.0 (Significant)

# %% [markdown]
# It appears that all the correlation of the variables are significant

# %%
# Prepare the data for features and target for machine learning
X = house.drop('price', axis=1)
y = house['price'].copy()

# %% [markdown]
#  - Drop the 'price' variable, as it is the target that we want to predict
#  - make a copy to the original dataframe, to avoid directly amend on it

# %% [markdown]
# ## Imputation

# %%
# Impute those null values with median
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(strategy="median")

imputer.fit(X)
X_imp = imputer.transform(X)

X = pd.DataFrame(X_imp, columns=X.columns)

# %% [markdown]
# ## Normalization

# %%
# Normalize the columns value

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X = scaler.fit_transform(X)

# %% [markdown]
# ## Test-train split

# %%
# Perform test-train split, to split training set and validation set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# # 5.3.2 Development & Testing of Machine Learning Models

# %% [markdown]
# ## Functions for checking accuracy & error

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score

def display_scores(model, X_train, y_train, X_test, y_test):
    def rmse(X, y):
        scores = cross_val_score(model, X, y,
                                 scoring="neg_mean_squared_error", cv=10)
        rmse_scores = np.sqrt(-scores)
        return rmse_scores
    rmse_train_scores = rmse(X_train, y_train)
    rmse_test_scores = rmse(X_test, y_test)
    
    # Model Scores
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    
    print("Training Set")
    print("-"*50)
    print("Training set: ", train_score)
    print("Scores: ", rmse_train_scores)
    print("Mean: ", rmse_train_scores.mean())
    print("Standard deviation: ", rmse_train_scores.std())
    print("\n"*2)
    print("Testing Set")
    print("-"*50)    
    print("Testing set: ", test_score)
    print("Scores: ", rmse_test_scores)
    print("Mean: ", rmse_test_scores.mean())
    print("Standard deviation: ", rmse_test_scores.std())
    
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    # Return the predictions & Scores on testing set
    return y_test_predict, rmse_test_scores, test_score

# %% [markdown]
# ## Linear Regression

# %%
# %%time
from sklearn.linear_model import LinearRegression

lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
# Out:
# Wall time: 214 ms
# LinearRegression()

# %%
lin_y_test_predict, lin_test_rmse, lin_test_score = display_scores(lin_model, X_train,
                                                                   y_train, X_test, y_test)
# Out:
# Training Set
# --------------------------------------------------
# Training set:  0.3922021305128296
# Scores:  [1.55398979e+04 1.54304302e+04 1.56293439e+04 2.91847728e+08
#  1.55110086e+04 1.55769351e+04 1.56182486e+04 1.56349769e+04
#  1.57163011e+04 1.55200834e+04]
# Mean:  29198790.504441958
# Standard deviation:  87549645.77145724
#
#
#
# Testing Set
# --------------------------------------------------
# Testing set:  0.38963802993207375
# Scores:  [15181.49349027 15602.00301256 15277.20618439 15728.88385498
#  15652.04596508 15769.55168678 15630.58089759 15473.9067273
#  15353.59897298 15589.38036114]
# Mean:  15525.86511530744
# Standard deviation:  187.11394909797588

# %% [markdown]
# ## Ridge

# %%
# %%time
from sklearn.linear_model import Ridge

ridge_model = Ridge()
ridge_model.fit(X_train, y_train);
# Out:
# Wall time: 53.9 ms
# Ridge()

# %%
ridge_y_test_predict, ridge_test_rmse, ridge_test_score = display_scores(ridge_model, X_train, 
                                                                      y_train, X_test, y_test)
# Out:
# Training Set
# --------------------------------------------------
# Training set:  0.39219690900606996
# Scores:  [15539.66696422 15430.72504947 15629.49268487 15557.34685628
#  15509.93875014 15576.25688942 15619.23764477 15635.57303581
#  15714.73912073 15520.42815732]
# Mean:  15573.340515302369
# Standard deviation:  75.949290861016
#
#
#
# Testing Set
# --------------------------------------------------
# Testing set:  0.38961320757772466
# Scores:  [15196.57206072 15617.22555004 15281.3113787  15735.94875968
#  15640.55392982 15765.82301535 15648.03248591 15482.96552874
#  15374.2384525  15615.33919114]
# Mean:  15535.801035259437
# Standard deviation:  183.91027746204216

# %% [markdown]
# ## Lasso

# %%
# %%time
from sklearn.linear_model import Lasso

lasso_model = Lasso()
lasso_model.fit(X_train, y_train)
# Out:
# Wall time: 243 ms
# Lasso()

# %%
lasso_y_test_predict, lasso_test_rmse, lasso_test_score  = display_scores(lasso_model, X_train, 
                                                                          y_train, X_test, y_test)
# Out:
# Training Set
# --------------------------------------------------
# Training set:  0.3921741931480308
# Scores:  [15539.47623686 15431.56720266 15630.30945467 15558.63895416
#  15508.53968402 15576.08661665 15619.37756722 15636.6136606
#  15714.20786669 15521.28811597]
# Mean:  15573.61053595055
# Standard deviation:  75.88806309911286
#
#
#
# Testing Set
# --------------------------------------------------
# Testing set:  0.3895536396958257
# Scores:  [15200.16141568 15614.85082674 15278.55141137 15735.72086776
#  15638.74566624 15767.60413668 15649.64432374 15481.60001413
#  15373.82171884 15612.36586039]
# Mean:  15535.306624157016
# Standard deviation:  183.6772928427326

# %% [markdown]
# Performing relatively bad on both linear and lasso, and ridge model

# %% [markdown]
# ## Decision Tree

# %%
# %%time
from sklearn.tree import DecisionTreeRegressor

tree_model = DecisionTreeRegressor()
tree_model.fit(X_train, y_train)
# Out:
# Wall time: 2.42 s
# DecisionTreeRegressor()

# %%
tree_y_test_predict, tree_test_rmse, tree_test_score = display_scores(tree_model, X_train, 
                                                                      y_train, X_test, y_test)
# Out:
# Training Set
# --------------------------------------------------
# Training set:  0.9998271083169152
# Scores:  [8786.27936344 8952.09686411 8739.3155326  8769.03105801 8797.18753036
#  8682.51046173 8901.74381074 8603.57001755 8742.95546118 8722.37851345]
# Mean:  8769.706861317038
# Standard deviation:  95.29641471850434
#
#
#
# Testing Set
# --------------------------------------------------
# Testing set:  0.8118590806488614
# Scores:  [ 9914.04163472  9934.09517613 10129.21537254 10207.07704409
#   9939.77295879  9812.26620146 10208.92765903  9792.8696414
#   9804.70002623 10039.35213875]
# Mean:  9978.231785313603
# Standard deviation:  152.21266297619673

# %% [markdown]
# ## Random Forest

# %%
# %%time
# Random Forest (Full)

from sklearn.ensemble import RandomForestRegressor


if os.path.isfile('randomforest.sav'):
    forest_model = load_model('randomforest.sav')
else:
    forest_model = RandomForestRegressor()
    forest_model.fit(X_train, y_train)
# Out:
# Wall time: 2min 23s

# %%
forest_y_test_predict, forest_test_rmse, forest_test_score = display_scores(forest_model, X_train, y_train, 
                                                               X_test, y_test)
# Out:
# Training Set
# --------------------------------------------------
# Training set:  0.9859197111929365
# Scores:  [6362.07413991 6475.11019085 6316.20443206 6387.71864043 6339.70027283
#  6296.49650404 6411.03797299 6357.78949902 6434.87263539 6396.09893029]
# Mean:  6377.710321780556
# Standard deviation:  51.737854747911165
#
#
#
# Testing Set
# --------------------------------------------------
# Testing set:  0.898987708829935
# Scores:  [7092.28775047 7244.6936723  7423.91627079 7504.32111199 7507.67920291
#  7121.99076411 7337.94371255 7189.33832306 7206.38143608 7275.36728212]
# Mean:  7290.391952636493
# Standard deviation:  141.51228196472596

# %%
# Save and load model
import pickle

def save_model(model, filename):
    """Save Machine Learning Model"""
    pickle.dump(model, open(filename, 'wb'))

def load_model(filename):
    """Load Machine Learning Model"""
    model = pickle.load(open(filename, 'rb'))
    return model 

# # for saving the model
# save_model(forest_model, 'randomforest.sav')

# # For loading the model 
# forest_model = load_model('randomforest.sav')

# %%
# %%time
## Support Vector Machine

from sklearn.svm import SVR

svm_model = SVR(kernel='rbf')
svm_model.fit(X_train, y_train)
# Out:
# Wall time: 19min 54s
# SVR()

# %%
svm_y_test_predict, svm_test_rmse, svm_test_score = display_scores(svm_model,X_train, y_train, 
                                                               X_test, y_test)

# %%
# %%time
# Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor

gb_model = GradientBoostingRegressor(random_state=0)
gb_model.fit(X_train, y_train)

# %%
gb_y_test_predict, gb_test_rmse, gb_test_score = display_scores(gb_model, X_train,
                                                                   y_train, X_test, y_test)

# %% [markdown]
# ## Deep Neural Network

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# %%
normalizer = preprocessing.Normalization()
normalizer.adapt(X_train)

# %%
def build_and_compile_model(norm):
    model = keras.Sequential([
      norm,
      layers.Dense(65, activation='relu'),
      layers.Dense(45, activation='relu'),
      layers.Dense(10, activation='relu'),
      layers.Dense(5, activation='relu'),
      layers.Dense(1)
    ])

    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
    return model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 20)                41
# _________________________________________________________________
# dense_58 (Dense)             (None, 65)                1365
# _________________________________________________________________
# dense_59 (Dense)             (None, 45)                2970
# _________________________________________________________________
# dense_60 (Dense)             (None, 10)                460
# _________________________________________________________________
# dense_61 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_62 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 4,897
# Trainable params: 4,856
# Non-trainable params: 41
# _________________________________________________________________

# %% [markdown]
#  sqrt(input layer nodes * output layer nodes)

# %% [markdown]
# ## Fitting deep neural network model

# %%
# %%time
history = dnn_model.fit(
    X_train, y_train,
    validation_split=0.2,
    verbose=1, epochs=300)
# Out:
# Epoch 1/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 23113.5081 - val_loss: 11724.9287
# Epoch 2/300
# 3025/3025 [==============================] - 5s 2ms/step - loss: 11497.4813 - val_loss: 11331.5654: 3s -
# Epoch 3/300
# 3025/3025 [==============================] - 5s 2ms/step - loss: 11225.4674 - val_loss: 11111.7441
# Epoch 4/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10955.9753 - val_loss: 10987.3496
# Epoch 5/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10865.8701 - val_loss: 10933.2070TA: 0s - los
# Epoch 6/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10736.8270 - val_loss: 10819.0518
# Epoch 7/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10743.5484 - val_loss: 10754.9639
# Epoch 8/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10576.0504 - val_loss: 10675.6475
# Epoch 9/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10528.4259 - val_loss: 10592.1074
# Epoch 10/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 10449.4076 - val_loss: 10503.6475
# Epoch 11/300
# 3025/3025 [==============================] - 5s 1ms/step - loss: 10337.5915 - val_loss: 10009.1016
# Epoch 12/300
# 3025/3025 [==============================] - 5s 2ms/step - loss:
300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 5804.4280 - val_loss: 5994.1143
# Epoch 271/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 5790.3776 - val_loss: 5998.9023
# Epoch 272/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5800.0277 - val_loss: 6031.6104
# Epoch 273/300
# 3025/3025 [==============================] - 8s 3ms/step - loss: 5843.7338 - val_loss: 5986.9482
# Epoch 274/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5782.7594 - val_loss: 6049.3745
# Epoch 275/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5779.6616 - val_loss: 5958.9497
# Epoch 276/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5780.8360 - val_loss: 6014.5059
# Epoch 277/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5806.0776 - val_loss: 6010.9946
# Epoch 278/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5781.0636 - val_loss: 6072.0176
# Epoch 279/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5779.5604 - val_loss: 6083.0732
# Epoch 280/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5796.7982 - val_loss: 5984.4150
# Epoch 281/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5800.4095 - val_loss: 6015.8848
# Epoch 282/300
# 3025/3025 [==============================] - 5s 2ms/step - loss: 5763.6068 - val_loss: 5996.6592
# Epoch 283/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5801.2351 - val_loss: 5977.5278
# Epoch 284/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5777.7254 - val_loss: 6032.7598
# Epoch 285/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5783.6492 - val_loss: 5992.3188
# Epoch 286/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5778.7154 - val_loss: 5993.1450
# Epoch 287/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5769.5773 - val_loss: 6008.0127
# Epoch 288/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5821.2272 - val_loss: 6022.9409
# Epoch 289/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5779.7564 - val_loss: 5978.9375
# Epoch 290/300
# 3025/3025 [==============================] - 7s 2ms/step - loss: 5798.6821 - val_loss: 6009.6753 - loss: 579
# Epoch 291/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5771.9450 - val_loss: 6019.0864
# Epoch 292/300
# 3025/3025 [==============================] - 5s 2ms/step - loss: 5767.5247 - val_loss: 5971.4766
# Epoch 293/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 5783.6293 - val_loss: 5966.2114
# Epoch 294/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 5794.9949 - val_loss: 6002.7686
# Epoch 295/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 5789.4370 - val_loss: 5963.5166
# Epoch 296/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5781.1227 - val_loss: 6024.4658
# Epoch 297/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5787.7863 - val_loss: 5968.9722
# Epoch 298/300
# 3025/3025 [==============================] - 6s 2ms/step - loss: 5768.4088 - val_loss: 5993.4312
# Epoch 299/300
# 3025/3025 [==============================] - 4s 1ms/step - loss: 5770.3084 - val_loss: 6034.2441
# Epoch 300/300
# 3025/3025 [==============================] - 5s 2ms/step - loss: 5769.9534 - val_loss: 5985.8921
# Wall time: 24min 17s

# %%
def plot_loss(history):
    """For ploting the losses over Epoch"""
    plt.figure(figsize=(20, 10))
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error [price]')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# ## Collect the results on the test set:

# %%
test_results = {}
test_results['dnn_model'] = dnn_model.evaluate(X_test, y_test, verbose=0)

# %%
test_results
# Out:
# {'dnn_model': 5938.43896484375}

# %%
## Prediction
dnn_y_test_predict = dnn_model.predict(X_test).flatten()

# %%
# # Save dnn model
# dnn_model.save('dnn_model')

# Load model
# dnn_model = tf.keras.models.load_model('dnn_model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-75274d92b264> in <module>
#       3
#       4 # Load model
# ----> 5 dnn_model = tf.keras.models.load_model('dnn_model')
#
# NameError: name 'tf' is not defined

# %%
import tensorflow_addons as tfa

def coefficient_R_dnn(y_true, y_predict):
    metric = tfa.metrics.r_square.RSquare()
    metric.update_state(y_true, y_predict)
    result = metric.result()
    rsquared = result.numpy()
    return rsquared

dnn_rsquared = coefficient_R_dnn(y_test, dnn_y_test_predict)

# %%
dnn_rsquared
# Out:
# 0.8236023

# %% [markdown]
# # 4.0 Results & Discussion

# %% [markdown]
# ## Overall Results

# %%
# Results
# R squared coefficient
R_squared = {
'R2 Coeffiicent':{
'Linear Regression': lin_test_score,
'Ridge Regression': ridge_test_score,
'Lasso Regression': lasso_test_score,
'Decision Tree': tree_test_score,
'Random Forest': forest_test_score,
'Support Vector Machine': svm_test_score,
'Gradient Boosting': gb_test_score,
'Deep Neural Network': dnn_test_score
}

# Root Mean Square Error
RMSE = {
'R_squared':{
'Linear Regression': lin_test_rmse,
'Ridge Regression': ridge_test_rmse,
'Lasso Regression': lasso_test_rmse,
'Decision Tree': tree_test_rmse,
'Random Forest': forest_test_rmse,
'Support Vector Machine': svm_test_rmse,
'Gradient Boosting': gb_test_rmse,
'Deep Neural Network': dnn_test_rmse
}

# %% [markdown]
# ## Visualize the predicted results for accuracy

# %% [markdown]
# ### Functions for visualize the prediction Results

# %%
# Function for plot
def match_plot(y_test=y_test, y_test_predict=None, name=None):
    """Plot Prediction & Actual Overlapping plot"""
    num = 100
    z1 = y_test[:num].to_list()
    z2 = y_test_predict[:num]
    
    # for the title for model name
    if name == None:
        name = ""
    else: 
        name = "[" + name + "]"

    df = pd.DataFrame(list(zip(z1, z2)), columns=['Actual', 'Predicted'])
    ax = df.plot(figsize=(10, 5), title=f'{name} Difference Between Actual & Predicted Price')
    ax.set_ylabel("Price (RMB/m2)")
    ax.set_xlabel("Count (Data)")
    return df;

# Function for plot
def plot_actual_predicted(y_test=y_test, y_test_predict=None, name=None):
    """
    Ploting Predicted vs. Actual Price graph
    Parameters
    --------------
    y_test : array, 
    y_predict : predicted y 
    title : title of the chart
    
    """
    if name == None:
        name = ""
    else:
        name = "[" + name + "]"
    
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.scatter(x=y_test, y=y_test_predict, alpha=0.2)
    ax.set(title=f"{name} Actual Price vs. Predicted Price", 
           xlabel='Actual Price (RMB)', ylabel='Predicted Price (RMB)');
    lims = [0, y_test.max()]
    _ = plt.plot(lims, lims, '--k')
    plt.show()
    
# Combine 2 plots
def check_plot(y_test, y_test_predict, name):
    """Display 2 plots together"""
    df = match_plot(y_test, y_test_predict, name)
    plot_actual_predicted(y_test, y_test_predict, name)
    
    return df

# %%
# Linear Regression
lin_df = check_plot(y_test=y_test, y_test_predict=lin_y_test_predict, name='Linear Regression')

# %%
# Lasso
lasso_df = check_plot(y_test, y_test_predict=lasso_y_test_predict, name='Lasso')

# %%
# ridge 
ridge_df = check_plot(y_test, y_test_predict=ridge_y_test_predict, name='Ridge')

# %%
# Decision Tree
tree_df = check_plot(y_test, y_test_predict=tree_y_test_predict, name='Decision Tree')

# %%
# Random Forest
forest_df = check_plot(y_test, y_test_predict=forest_y_test_predict, name='Random Forest')

# %%
# Support Vector Machine
svm_df = check_plot(y_test_s, y_test_predict=svm_y_test_predict, name='Support Vector Machine')

# %%
# Gradient Boosting
gb_df = check_plot(y_test, y_test_predict=gbm_y_test_predict, name='Gradient Boosting')

# %%
# Deep Neural Network
dnn_df = check_plot(y_test, y_test_predict=dnn_y_test_predict, name='Deep Neural Network')

# %% [markdown]
# ## Visualzie for Deep Neural Networks
